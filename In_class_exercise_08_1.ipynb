# %% [markdown]
# <a href="https://colab.research.google.com/github/rubabshz/Rubab_INFO5731_Spring2020/blob/main/In_class_exercise_08_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **The eighth in-class-exercise (20 points in total, 3/30/2021)**

# %% [markdown]
# The data for this exercise is from the dataset you created from assignment three. Please perform answer the following questions based on your data:

# %% [markdown]
# ## (1) (10 points) Write a python program to extract the sentiment related terms from the corpus. You may use python package such as polyglot or external lexicon resources in the question. Rank the sentiment related terms by frequency.

# %%
# !pip install polyglot
# !pip install pyicu
# !pip install morfessor
# Out:
# Collecting polyglot
#   Downloading https://files.pythonhosted.org/packages/e7/98/e24e2489114c5112b083714277204d92d372f5bbe00d5507acf40370edb9/polyglot-16.7.4.tar.gz (126kB)
#      |████████████████████████████████| 133kB 5.6MB/s
# Building wheels for collected packages: polyglot
#   Building wheel for polyglot (setup.py) ... done
#   Created wheel for polyglot: filename=polyglot-16.7.4-py2.py3-none-any.whl size=52557 sha256=a6fd0dc79dca9c3232ccb5e9c44ac8816a543a3d6a8dd140ab75a41d2f41a564
#   Stored in directory: /root/.cache/pip/wheels/5e/91/ef/f1369fdc1203b0a9347d4b24f149b83a305f39ab047986d9da
# Successfully built polyglot
# Installing collected packages: polyglot
# Successfully installed polyglot-16.7.4
# Collecting pyicu
#   Downloading https://files.pythonhosted.org/packages/31/46/fa08c8efae2951e67681ec24319f789fc1a74e2096dd74373e34c79319de/PyICU-2.6.tar.gz (233kB)
#      |████████████████████████████████| 235kB 5.2MB/s
# Building wheels for collected packages: pyicu
#   Building wheel for pyicu (setup.py) ... done
#   Created wheel for pyicu: filename=PyICU-2.6-cp37-cp37m-linux_x86_64.whl size=1306388 sha256=0205683388dcb946e483e0130d5b27b7618b95fe2e6f9f71447a885e0cede5af
#   Stored in directory: /root/.cache/pip/wheels/31/21/2f/1c91831e8a93537ab21f6b4b935781b681104635fdb0315791
# Successfully built pyicu
# Installing collected packages: pyicu
# Successfully installed pyicu-2.6
# Collecting morfessor
#   Downloading https://files.pythonhosted.org/packages/39/e6/7afea30be2ee4d29ce9de0fa53acbb033163615f849515c0b1956ad074ee/Morfessor-2.0.6-py3-none-any.whl
# Installing collected packages: morfessor
# Successfully installed morfessor-2.0.6

# %%
pip install pycld2
# Out:
# Collecting pycld2
#   Downloading https://files.pythonhosted.org/packages/21/d2/8b0def84a53c88d0eb27c67b05269fbd16ad68df8c78849e7b5d65e6aec3/pycld2-0.41.tar.gz (41.4MB)
#      |████████████████████████████████| 41.4MB 107kB/s
# Building wheels for collected packages: pycld2
#   Building wheel for pycld2 (setup.py) ... done
#   Created wheel for pycld2: filename=pycld2-0.41-cp37-cp37m-linux_x86_64.whl size=9834260 sha256=d8ec463b16190bcf5c53f28c57e88d7d476897fd4dc28f42cb549f4d3f28bdcf
#   Stored in directory: /root/.cache/pip/wheels/c6/8f/e9/08a1a8932a490175bd140206cd86a3dbcfc70498100de11079
# Successfully built pycld2
# Installing collected packages: pycld2
# Successfully installed pycld2-0.41

# %%
from polyglot.downloader import downloader
downloader.download("embeddings2.en")
# !polyglot download sentiment2.en
#!polyglot download sentiment2.qu
#!polyglot download sentiment2.nl
#!polyglot download sentiment2.zzp
# !polyglot download morph2.en
#!polyglot download LANG:ar
# Out:
# [polyglot_data] Downloading package embeddings2.en to
# [polyglot_data]     /root/polyglot_data...
# [polyglot_data]   Package embeddings2.en is already up-to-date!
# [polyglot_data] Downloading package sentiment2.en to
# [polyglot_data]     /root/polyglot_data...
# [polyglot_data]   Package sentiment2.en is already up-to-date!
# [polyglot_data] Downloading package morph2.en to
# [polyglot_data]     /root/polyglot_data...
# [polyglot_data]   Package morph2.en is already up-to-date!

# %%
# %%bash
# polyglot download sentiment2.en
# Out:
# [polyglot_data] Downloading package sentiment2.en to
# [polyglot_data]     /root/polyglot_data...
# [polyglot_data]   Package sentiment2.en is already up-to-date!

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import pandas as pd

#df = nltk.download('punkt')
#with open("/content/CleanData.csv", "r", encoding='utf-8') as file:
 #    data = file.read()

# %%
df = pd.read_csv('/content/CleanData.csv')
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
from nltk.corpus import stopwords
from textblob import TextBlob
df['cleaned_text'] = df['cleaned_text'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df['cleaned_text'] = df['cleaned_text'].str.replace('[^\w\s]','')
stop = stopwords.words('english')
df['cleaned_text'] = df['cleaned_text'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df['cleaned_text'] = df['cleaned_text'].apply(lambda x: str(TextBlob(x).correct()))

# %%
from polyglot.text import Text

# %%
sentimental_words = ['Sentimental Words']
for line in df['cleaned_text']:
  text = Text(line)
  #print("{:<16}{}".format("Word", "Polarity")+"\n"+"-"*30)
  for w in text.words:
    #if w.polarity != 0:
      sentimental_words.append(w)
  #print("{:<16}{:>2}".format(w, w.polarity))
sentimental_words
# Out:
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# Detector is not able to detect the language reliably.
# ['Sentimental Words',
#  'b',
#  'march',
#  'pm',
#  'eat',
#  'real',
#  'time',
#  'mapping',
#  'wuhancoronavirus',
#  'nov',
#  'global',
#  'case',
#  'confirmed',
#  'case',
#  'andre',
#  'x',
#  'a',
#  'http',
#  'co',
#  'twy',
#  'loss',
#  'b',
#  'today',
#  'massachusetts',
#  'penalized',
#  'rest',
#  'wuhancoronavirus',
#  'vaccination',
#  'timeline',
#  'yet',
#  'still',
#  'sexe',
#  'x',
#  'a',
#  'http',
#  'co',
#  'lwulsrpm',
#  'w',
#  'b',
#  'shall',
#  'forever',
#  'wuhancoronavirus',
#  'http',
#  'co',
#  'ipcmob',
#  'cow',
#  'b',
#  'truth',
#  'could',
#  'xefxbcx',
#  'ne',
#  'x',
#  'made',
#  'x',
#  'x',
#  'he',
#  'x',
#  'x',
#  'he',
#  'tax',
#  'he',
#  'xadxa',
#  'he',
#  'x',
#  'x',
#  'he',
#  'tax',
#  'eye',
#  'tax',
#  'ce',
#  'xaexa',
#  'n',
#  'laborunfall',
#  'sarco',
#  'sarco',
#  'virus',
#  'pandemienxe',
#  'x',
#  'table',
#  'x',
#  'xbdxe',
#  'a',
#  'a',
#  'drlimengyannxc',
#  'a',
#  'he',
#  'x',
#  'a',
#  'http',
#  'co',
#  's',
#  'q',
#  'j',
#  'b',
#  'state',
#  'department',
#  'lead',
#  'investigator',
#  'say',
#  'flumanchu',
#  'may',
#  'escaped',
#  'lab',
#  'nnhttps',
#  'co',
#  'eotcqetzj',
#  'nnviaxe',
#  'x',
#  'a',
#  'http',
#  'co',
#  'q',
#  'uqffjt',
#  'b',
#  'tears',
#  'fired',
#  'ne',
#  'x',
#  'c',
#  'he',
#  'face',
#  'http',
#  'co',
#  'nkacos',
#  'old',
#  'nncoronaviruschina',
#  'pndahuggerncoronachan',
#  'coronachan',
#  'he',
#  'x',
#  'x',
#  'he',
#  'x',
#  'made',
#  'x',
#  'x',
#  'axe',
#  'x',
#  'a',
#  'he',
#  'x',
#  'x',
#  'he',
#  'x',
#  'x',
#  'he',
#  'x',
#  'a',
#  'http',
#  'co',
#  'cyst',
#  'b',
#  'layman',
#  'timobrien',
#  'calling',
#  'china',
#  'virus',
#  'problem',
#  'asia',
#  'hate',
#  'problem',
#  'done',
#  'x',
#  'x',
#  'mix',
#  'ni',
#  'aside',
#  'x',
#  'a',
#  'http',
#  'co',
#  'lb',
#  'in',
#  'u',
#  'b',
#  'calling',
#  'china',
#  'virus',
#  'problem',
#  'asia',
#  'hate',
#  'problem',
#  'done',
#  'x',
#  'x',
#  'mix',
#  'ni',
#  'asia',
#  'call',
#  'the',
#  'x',
#  'a',
#  'http',
#  'co',
#  'qjhycep',
#  'b',
#  'timobrien',
#  'calling',
#  'china',
#  'virus',
#  'problem',
#  'asia',
#  'hate',
#  'problem',
#  'done',
#  'x',
#  'x',
#  'mix',
#  'ni',
#  'asia',
#  'ice',
#  'x',
#  'a',
#  'http',
#  'co',
#  'e',
#  'z',
#  'vlwdr',
#  'b',
#  'mmpadellan',
#  'ok',
#  'thenwuhancoronavirusnwuflunkungflunwuhanchinesecoronavirus',
#  'b',
#  'gordongchang',
#  'long',
#  'long',
#  'world',
#  'nnccpchina',
#  'held',
#  'accountable',
#  'in',
#  'hongkong',
#  'n',
#  'he',
#  'x',
#  'a',
#  'http',
#  'co',
#  'okay',
#  'bone',
#  'b',
#  'tramp',
#  'accomplishment',
#  'term',
#  'add',
#  'noble',
#  'peace',
#  'prize',
#  'nomination',
#  'actual',
#  'accomplishment',
#  'inch',
#  'promote',
#  'x',
#  'a',
#  'http',
#  'co',
#  'in',
#  'swlzq',
#  'b',
#  'march',
#  'pm',
#  'eat',
#  'real',
#  'time',
#  'mapping',
#  'wuhancoronavirus',
#  'nov',
#  'global',
#  'case',
#  'confirmed',
#  'case',
#  'andre',
#  'x',
#  'a',
#  'http',
#  'co',
#  'with',
#  'b',
#  'truth',
#  'could',
#  'xefxbcx',
#  'ne',
#  'x',
#  'made',
#  'x',
#  'x',
#  'he',
#  'x',
#  'x',
#  'he',
#  'tax',
#  'he',
#  'xadxa',
#  'he',
#  'x',
#  'x',
#  'he',
#  'tax',
#  'eye',
#  'tax',
#  'ce',
#  'xaexa',
#  'n',
#  'laborunfall',
#  'sarco',
#  'sarco',
#  'virus',
#  'pandemienxe',
#  'x',
#  'table',
#  'x',
#  'xbdxe',
#  'a',
#  'a',
#  'drlimengyannxc',
#  'a',
#  'he',
#  'x',
#  'a',
#  'http',
#  'co',
#  'in',
#  'bad',
#  'b',
#  'truth',
#  'could',
#  'xefxbcx',
#  'ne',
#  'x',
#  'made',
#  'x',
#  'x',
#  'he',
#  'x',
#  'x',
#  'he',
#  'tax',
#  'he',
#  'xadxa',
#  'he',
#  'x',
#  'x',
#  'he',
#  'tax',
#  'eye',
#  'tax',
#  'ce',
#  'xaexa',
#  'n',
#  'laborunfall',
#  'sarco',
#  'sarco',
#  'virus',
#  'pandemienxe',
#  'x',
#  'table',
#  'x',
#  'xbdxe',
#  'a',
#  'a',
#  'drlimengyannxc',
#  'a',
#  'he',
#  'x',
#  'a',
#  'http',
#  'co',
#  'you',
#  'ygfjpr',
#  'b',
#  'truth',
#  'could',
#  'xefxbcx',
#  'ne',
#  'x',
#  'made',
#  'x',
#  'x',
#  'he',
#  'x',
#  'x',
#  'he',
#  'tax',
#  'he',
#  'xadxa',
#  'he',
#  'x',
#  'x',
#  'he',
#  'tax',
#  'eye',
#  'tax',
#  'ce',
#  'xaexa',
#  'n',
#  'laborunfall',
#  'sarco',
#  'sarco',
#  'virus',
#  'pandemienxe',
#  'x',
#  'table',
#  'x',
#  'xbdxe',
#  'a',
#  'a',
#  'drlimengyannxc',
#  'a',
#  'he',
#  'x',
#  'a',
#  'http',
#  'co',
#  'in',
#  'run',
#  'go',
#  'b',
#  'tears',
#  'fired',
#  'ne',
#  'x',
#  'c',
#  'he',
#  'face',
#  'http',
#  'co',
#  'nkacos',
#  'old',
#  'ncoronaviruschina',
#  'pndahuggerncoronachan',
#  'coronachan',
#  'he',
#  'x',
#  'x',
#  'he',
#  'x',
#  'made',
#  'x',
#  'x',
#  'axe',
#  'x',
#  'a',
#  'he',
#  'x',
#  'x',
#  'he',
#  'x',
#  'x',
#  'he',
#  'x',
#  'a',
#  'http',
#  'co',
#  'yjelptq',
#  'br',
#  'b',
#  'globaltimesnews',
#  'could',
#  'impact',
#  'thanks',
#  'dirty',
#  'wet',
#  'market',
#  'wuhannnwuhanvirus',
#  'wuhancoronavirus',
#  'china',
#  'x',
#  'a',
#  'http',
#  'co',
#  'a',
#  'who',
#  'b',
#  'sharpiedj',
#  'michaelpsenger',
#  'forgot',
#  'infected',
#  'ccpvirus',
#  'wuhancoronavirus',
#  'past',
#  'b',
#  'india',
#  'of',
#  'x',
#  'ff',
#  'xaexf',
#  'x',
#  'ff',
#  'x',
#  'example',
#  'supplying',
#  'vaccine',
#  'country',
#  'nwuhancoronavirus',
#  'anaemic',
#  'destroyed',
#  'world',
#  'of',
#  'x',
#  'ff',
#  'c',
#  'n',
#  'were',
#  'x',
#  'a',
#  'http',
#  'co',
#  'am',
#  'wicxtwf',
#  'b',
#  'mattwridley',
#  'wuhancoronavirus',
#  'spread',
#  'world',
#  'thanks',
#  'help',
#  'cap',
#  'cap',
#  'concealment',
#  'x',
#  'a',
#  'http',
#  'co',
#  'ylwjc',
#  'go',
#  'b',
#  'march',
#  'pm',
#  'eat',
#  'real',
#  'time',
#  'mapping',
#  'wuhancoronavirus',
#  'nov',
#  'global',
#  'case',
#  'confirmed',
#  'case',
#  'andre',
#  'x',
#  'a',
#  'http',
#  'co',
#  'xxxi',
#  'hut',
#  'b',
#  'state',
#  'allow',
#  'type',
#  'diabetic',
#  'get',
#  'vaccinated',
#  'stage',
#  'massachusetts',
#  'massgovernor',
#  'charliebakermaxe',
#  'x',
#  'a',
#  'http',
#  'co',
#  'by',
#  'graf',
#  'b',
#  'ianmsc',
#  'wuhancoronavirus',
#  'already',
#  'halloween',
#  'virus',
#  'fundamentals',
#  'want',
#  'hear',
#  'b',
#  'min',
#  'investigation',
#  'thelizhayes',
#  'wuhancoronavirus',
#  'spread',
#  'world',
#  'thanks',
#  'here',
#  'x',
#  'a',
#  'http',
#  'co',
#  'rkvsuq',
#  'b',
#  'repbrianmast',
#  'wuhancoronavirus',
#  'spread',
#  'world',
#  'thanks',
#  'help',
#  'cap',
#  'cap',
#  'concealment',
#  'x',
#  'a',
#  'http',
#  'co',
#  'pfclhsnw',
#  'b',
#  'repbrianmast',
#  'wuhancoronavirus',
#  'spread',
#  'world',
#  'thanks',
#  'help',
#  'cap',
#  'cap',
#  'concealment',
#  'x',
#  'a',
#  'http',
#  'co',
#  'so',
#  'vvhlr',
#  'b',
#  'globaltimesnews',
#  'parisian',
#  'citizen',
#  'known',
#  'guinea',
#  'pig',
#  'chinese',
#  'experiment',
#  'time',
#  'poor',
#  'quality',
#  'x',
#  'a',
#  'http',
#  'co',
#  'of',
#  'cixfxr',
#  'b',
#  'hotmanila',
#  'william',
#  'blunders',
#  'slightly',
#  'behind',
#  'wuhancoronavirus',
#  'w',
#  'k',
#  'da',
#  'soon',
#  'hand',
#  'still',
#  'waaaay',
#  'ahead',
#  'k',
#  'amp',
#  'still',
#  'rising',
#  'b',
#  'china',
#  'seen',
#  'fair',
#  'china',
#  'allow',
#  'foreigner',
#  'contracted',
#  'wuhancoronavirus',
#  'enter',
#  'pre',
#  'b',
#  'march',
#  'pm',
#  'eat',
#  'real',
#  'time',
#  'mapping',
#  'wuhancoronavirus',
#  'nov',
#  'global',
#  'case',
#  'confirmed',
#  'case',
#  'andre',
#  'x',
#  'a',
#  'http',
#  'co',
#  'n',
#  'rptyzu',
#  'b',
#  'thisisgba',
#  'china',
#  'could',
#  'simplify',
#  'isa',
#  'policy',
#  'foreigner',
#  'applying',
#  'enter',
#  'chinese',
#  'mainland',
#  'via',
#  'he',
#  'have',
#  'x',
#  'a',
#  'http',
#  'co',
#  'fsiqevb',
#  'x',
#  'b',
#  'snowflakstears',
#  'still',
#  'waiting',
#  'extra',
#  'week',
#  'spring',
#  'break',
#  'deborah',
#  'bird',
#  'two',
#  'were',
#  'x',
#  'a',
#  'http',
#  'co',
#  'pe',
#  'ozddfcu',
#  'b',
#  'globaltimesnews',
#  'what',
#  'epicentre',
#  'coronavirus',
#  'could',
#  'nnchinavirus',
#  'wuhanvirusxe',
#  'x',
#  'a',
#  'http',
#  'co',
#  'oftefquuq',
#  'b',
#  'repbrianmast',
#  'wuhancoronavirus',
#  'spread',
#  'world',
#  'thanks',
#  'help',
#  'cap',
#  'cap',
#  'concealment',
#  'x',
#  'a',
#  'http',
#  'co',
#  'zxvuzqhuho',
#  'b',
#  'tears',
#  'fired',
#  'ne',
#  'x',
#  'c',
#  'he',
#  'face',
#  'http',
#  'co',
#  'nkacos',
#  'old',
#  'nncoronaviruschina',
#  'pndahuggerncoronachan',
#  'coronachan',
#  'he',
#  'x',
#  'x',
#  'he',
#  'x',
#  'made',
#  'x',
#  'x',
#  'axe',
#  'x',
#  'a',
#  'he',
#  'x',
#  'x',
#  'he',
#  'x',
#  'x',
#  'he',
#  'x',
#  'a',
#  'http',
#  'co',
#  'g',
#  'z',
#  'say',
#  'w',
#  'b',
#  'catcarterpi',
#  'wuhancoronavirus',
#  'b',
#  'march',
#  'pm',
#  'eat',
#  'real',
#  'time',
#  'mapping',
#  'wuhancoronavirus',
#  'nov',
#  'global',
#  'case',
#  'confirmed',
#  'case',
#  'andre',
#  'x',
#  'a',
#  'http',
#  'co',
#  'man',
#  'jug',
#  'b',
#  'carolynhparrish',
#  'amazon',
#  'amazon',
#  'every',
#  'right',
#  'fight',
#  'shutdown',
#  'order',
#  'irresponsible',
#  'canadian',
#  'political',
#  'x',
#  'a',
#  'http',
#  'co',
#  'by',
#  'nut',
#  'b',
#  'globaltimesnews',
#  'lmaonnno',
#  'amount',
#  'crossing',
#  'going',
#  'change',
#  'history',
#  'book',
#  'what',
#  'epicexe',
#  'x',
#  'a',
#  'http',
#  'co',
#  'hvgeoa',
#  'he',
#  'b',
#  'say',
#  'person',
#  'whose',
#  'country',
#  'spread',
#  'wuhancoronavirus',
#  'chinesevirus',
#  'ccpvirus',
#  'http',
#  'co',
#  'jtkwhz',
#  'hut',
#  'b',
#  'sankeinews',
#  'japan',
#  'could',
#  'hold',
#  'olympics',
#  'probably',
#  'anaemic',
#  'caused',
#  'be',
#  'x',
#  'a',
#  'http',
#  'co',
#  'lamp',
#  'the',
#  'b',
#  'amazon',
#  'amazon',
#  'canadian',
#  'authority',
#  'shut',
#  'warehouse',
#  'hampton',
#  'ontario',
#  'biting',
#  'spread',
#  'of',
#  'x',
#  'a',
#  'http',
#  'co',
#  'ldynufik',
#  'b',
#  'jillpromoli',
#  'allowing',
#  'march',
#  'meeting',
#  'hampton',
#  'also',
#  'contributes',
#  'wuhancoronavirus',
#  'situation',
#  'nnhttps',
#  'co',
#  'felt',
#  'h',
#  'b',
#  'tears',
#  'fired',
#  'ne',
#  'x',
#  'c',
#  'he',
#  'face',
#  'http',
#  'co',
#  'nkacos',
#  'old',
#  'ncoronaviruschina',
#  'pndahuggerncoronachan',
#  'coronachan',
#  'he',
#  'x',
#  'x',
#  'he',
#  'x',
#  'made',
#  'x',
#  'x',
#  'axe',
#  'x',
#  'a',
#  'he',
#  'x',
#  'x',
#  'he',
#  'x',
#  'x',
#  'he',
#  'x',
#  'a',
#  'http',
#  'co',
#  'jwftcftovl',
#  'b',
#  'agree',
#  'thing',
#  'started',
#  'getting',
#  'normal',
#  'covidiots',
#  'missed',
#  'refusing',
#  'wearamask',
#  'amp',
#  'me',
#  'x',
#  'a',
#  'http',
#  'co',
#  'fsqjrijq',
#  'x',
#  'b',
#  'march',
#  'pm',
#  'eat',
#  'real',
#  'time',
#  'mapping',
#  'wuhancoronavirus',
#  'nov',
#  'global',
#  'case',
#  'confirmed',
#  'case',
#  'andre',
#  'x',
#  'a',
#  'http',
#  'co',
#  'item',
#  'gxtym',
#  'b',
#  'beermug',
#  'k',
#  'besides',
#  'prevent',
#  'throwing',
#  'sick',
#  'old',
#  'people',
#  'nursing',
#  'home',
#  'height',
#  'wuhancoronavirus',
#  ...]

# %%
from collections import Counter
frequencies = Counter(sentimental_words)
rank_df = pd.DataFrame(list(frequencies.most_common()), columns=['Words', 'Frequencies'])
rank_df.index = list(range(1, len(frequencies.most_common())+1))
rank_df
# Out:
#           Words  Frequencies
# 1             x          324
# 2            he          156
# 3             a          135
# 4             b           77
# 5            co           73
# ..          ...          ...
# 436        coxa            1
# 437   aafteqiaz            1
# 438          re            1
# 439    xsuiyyml            1
# 440  mixntrvhcv            1
#
# [440 rows x 2 columns]

# %% [markdown]
# ## (2) (10 points) Compare the performance of the following tools in sentiment identification: TextBlob (https://textblob.readthedocs.io/en/dev/), VADER (https://github.com/cjhutto/vaderSentiment), TFIDF-based Support Vector Machine (SVM) (Split your data into training and testing data). Take your own annotation as the standard answers.
#
# Reference code: https://towardsdatascience.com/fine-grained-sentiment-analysis-in-python-part-1-2697bb111ed4

# %%
def Encoder(senti):
  sentiment_encoded = 0
  if senti == 'Positive':
    sentiment_encoded = 1
  elif senti == 'Negative':
    sentiment_encoded = 2
  return sentiment_encoded

# %%
actual_sentiment = []
for senti in df['Sentiment']:
  actual_sentiment.append(Encoder(senti))

# %%
from textblob import TextBlob
textblob_sentiments = []
for line in df['cleaned_text']:
  polarity = TextBlob(line).sentiment.polarity
  if polarity > 0:
    textblob_sentiments.append(1)
  elif polarity < 0:
    textblob_sentiments.append(2)
  elif polarity == 0.0:
    textblob_sentiments.append(0)
text_blob_df = pd.DataFrame(list(zip(df['cleaned_text'], actual_sentiment, textblob_sentiments)), columns = ['Cleaned_text', 'Actual', 'Predicted'])
text_blob_df
# Out:
#                                          Cleaned_text  Actual  Predicted
# 0   b march pm eat real time mapping wuhancoronavi...       0          1
# 1   b today massachusetts penalized rest wuhancoro...       1          0
# 2   b shall forever wuhancoronavirus http co ipcmo...       0          2
# 3   b truth could xefxbcx ne x made x x he x x he ...       0          0
# 4   b state department lead investigator say fluma...       2          0
# ..                                                ...     ...        ...
# 72  b truth could xefxbcx ne x made x x he x x he ...       0          0
# 73  b truth could xefxbcx ne x made x x he x x he ...       0          0
# 74  b truth could xefxbcx ne x made x x he x x he ...       0          0
# 75  b truth could xefxbcx ne x made x x he x x he ...       0          0
# 76  b truth could xefxbcx ne x made x x he x x he ...       0          0
#
# [77 rows x 3 columns]

# %%
from sklearn.metrics import f1_score, accuracy_score
text_blob_accuracy = accuracy_score(text_blob_df['Actual'], text_blob_df['Predicted'])*100
text_blob_f1_score = f1_score(text_blob_df['Actual'], text_blob_df['Predicted'], average = 'macro')
print("Text Blob Accuracy is {0} and F1 Score is {1}".format(text_blob_accuracy, text_blob_f1_score))
# Out:
# Text Blob Accuracy is 49.35064935064935 and F1 Score is 0.40699515538225217

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
vader = SentimentIntensityAnalyzer()
vader_sentiments = []
for line in df['cleaned_text']:
  polarity = vader.polarity_scores(line)['compound']
  if polarity > 0:
    vader_sentiments.append(1)
  elif polarity < 0:
    vader_sentiments.append(2)
  elif polarity == 0.0:
    vader_sentiments.append(0)
vader_df = pd.DataFrame(list(zip(df['cleaned_text'], actual_sentiment, vader_sentiments)), columns = ['Cleaned_text', 'Actual', 'Predicted'])
vader_df
# Out:
# /usr/local/lib/python3.7/dist-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "
#                                          Cleaned_text  Actual  Predicted
# 0   b march pm eat real time mapping wuhancoronavi...       0          2
# 1   b today massachusetts penalized rest wuhancoro...       1          0
# 2   b shall forever wuhancoronavirus http co ipcmo...       0          0
# 3   b truth could xefxbcx ne x made x x he x x he ...       0          1
# 4   b state department lead investigator say fluma...       2          0
# ..                                                ...     ...        ...
# 72  b truth could xefxbcx ne x made x x he x x he ...       0          1
# 73  b truth could xefxbcx ne x made x x he x x he ...       0          1
# 74  b truth could xefxbcx ne x made x x he x x he ...       0          1
# 75  b truth could xefxbcx ne x made x x he x x he ...       0          1
# 76  b truth could xefxbcx ne x made x x he x x he ...       0          1
#
# [77 rows x 3 columns]

# %%
from sklearn.metrics import f1_score, accuracy_score
vader_accuracy = accuracy_score(vader_df['Actual'], vader_df['Predicted'])*100
vader_f1_score = f1_score(vader_df['Actual'], vader_df['Predicted'], average = 'macro')
print("Vader Accuracy is {0} and F1 Score is {1}".format(vader_accuracy, vader_f1_score))
# Out:
# Vader Accuracy is 32.467532467532465 and F1 Score is 0.3158617617580459

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
TFid_vectorizer = TfidfVectorizer(min_df = 5,
                             max_df = 0.8,
                             sublinear_tf = True,
                             use_idf = True)

# %%
Train_X, Test_X, Train_Y, Test_Y = train_test_split(df['cleaned_text'],df['Sentiment'],test_size=0.33)
Encoder = LabelEncoder()
Train_Y = Encoder.fit_transform(Train_Y)
Test_Y = Encoder.fit_transform(Test_Y)
Train_X_vectors = TFid_vectorizer.fit_transform(Train_X)
Test_X_vectors = TFid_vectorizer.transform(Test_X)

# %%
from sklearn import svm
from sklearn.metrics import classification_report
svm_model = svm.SVC(kernel='linear')
svm_model.fit(Train_X_vectors, Train_Y)
predicted = svm_model.predict(Test_X_vectors)
report = classification_report(Test_Y, predicted, output_dict=True)
report
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# {'0': {'f1-score': 0.0, 'precision': 0.0, 'recall': 0.0, 'support': 8},
#  '1': {'f1-score': 0.7906976744186047,
#   'precision': 0.6538461538461539,
#   'recall': 1.0,
#   'support': 17},
#  '2': {'f1-score': 0.0, 'precision': 0.0, 'recall': 0.0, 'support': 1},
#  'accuracy': 0.6538461538461539,
#  'macro avg': {'f1-score': 0.26356589147286824,
#   'precision': 0.21794871794871795,
#   'recall': 0.3333333333333333,
#   'support': 26},
#  'weighted avg': {'f1-score': 0.5169946332737031,
#   'precision': 0.42751479289940825,
#   'recall': 0.6538461538461539,
#   'support': 26}}

# %% [markdown]
#             Accuracy ,    F1 Score
#
# TextBlob              49.35  ,      0.406
# Vader                 32.46  ,      0.315
# SVM                   65.38  ,      0.0
